# %% [markdown]
# # Optimal Growth Model with Policy Function Iteration using Julia

# %%
using BenchmarkTools
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
mutable struct Model
    # primitive parameter
    beta::Float64 #subjective discount factor
    sigma::Float64 # relative risk aversion
    delta::Float64 #depriciation rate
    alpha::Float64 # capital share

    # discretize asset space
    agrid::Array{Float64,1}
end


# working like np.argmax(matrix,axis=1)
function argmax(mat::Array{Float64,2})
    values, indices = findmax(mat,2)
    return ind2sub(size(mat),vec(indices))[2]
end

function PFI(m::Model)
    beta = m.beta
    sigma = m.sigma
    alpha = m.alpha
    delta = m.delta
    
    agrid =m.agrid
    const na = size(agrid, 1)
    
    #utility function
    u(c::Float64) = (c^(1.0-sigma))/(1.0-sigma)
    
    const penalty::Float64 = -1e10
    
    #initialize value function and so on
    util = zeros(na,na) # utility matrix
    reward = zeros(na,1) # new utility using policy
    v0 = zeros(na,1) # initial guess of value function
    Tv = zeros(na,1) # update value function
    pol_a =zeros(na,1) # policy function
    a_index::Array{Int64,1} =zeros(na)
    I = speye(na) # create sparse identity matrix
        
    
    #create consuption and utility matrix        
    for (i,today) in enumerate(agrid)
        for (j,next) in enumerate(agrid)
            c = today ^ alpha + (1.0-delta)*today - next
            @inbounds util[i,j] = u(c)
            if c <= 0.0
                @inbounds util[i,j] = penalty
            end
        end
    end

    #iteration settings
    const maxiter = 1000
    const tol =1e-5

    # Policy function iteration and using monotonicity
    for iter in 1 : maxiter
        gridstart::Int64 =1
        # calculate temp value function
        for i in 1:na
            vmin = penalty
            for j in gridstart:na
                @inbounds v = util[i,j] + beta*v0[j]
                if v > vmin
                    vmin = copy(v)
                    gridstart = j
                else
                    break
                end
            end
            @inbounds a_index[i] = gridstart
        end
        
        #a_index = argmax(v) # obtain policy function ver. index
        Q = spzeros(na,na)
        for i in 1:na
            @inbounds reward[i] = u(agrid[i]^alpha + (1.0-delta)*agrid[i] - agrid[a_index[i]])#pol_a[i]) 
            @inbounds Q[i,a_index[i]] = 1.0
        end
        
        Tv = (I-beta*Q)\reward
        
        error = maximum(abs.(Tv-v0)) # update error
        v0    = copy(Tv) # update value function
        
        if error < tol
            for i in 1:na
                @inbounds pol_a[i]   = agrid[a_index[i]]
            end
            break
        end
    end
    
    return(agrid,v0,pol_a)
end
# Out:
# PFI (generic function with 1 method)

# %%
beta = 0.95 #subjective discount factor
sigma = 2.0 # relative risk aversion
delta = 0.1 #depriciation rate
alpha = 0.33 # capital share

# Steady state
aterm = 1.0/beta -(1.0 -delta)
kstar = alpha/aterm
kstar = kstar^(1.0/(1.0-alpha))

amin = 0.1 * kstar
amax = 2.0 * kstar
na   = 250

model = Model(beta, sigma, delta, alpha, linspace(amin, amax, na))
# Out:
# WARNING: imported binding for beta overwritten in module Main
# Model(0.95, 2.0, 0.1, 0.33, [0.316086, 0.340205, 0.364324, 0.388443, 0.412562, 0.436681, 0.4608, 0.484919, 0.509038, 0.533157  …  6.10465, 6.12877, 6.15289, 6.17701, 6.20113, 6.22524, 6.24936, 6.27348, 6.2976, 6.32172])

# %%
agrid,v0, pol_a = PFI(model)
# Out:
# ([0.316086, 0.340205, 0.364324, 0.388443, 0.412562, 0.436681, 0.4608, 0.484919, 0.509038, 0.533157  …  6.10465, 6.12877, 6.15289, 6.17701, 6.20113, 6.22524, 6.24936, 6.27348, 6.2976, 6.32172], [-22.9351; -22.7698; … ; -15.6819; -15.672], [0.484919; 0.509038; … ; 5.95994; 5.95994])

# %%
@time PFI(model);
# Out:
#   0.015313 seconds (2.38 k allocations: 4.676 MiB)

# %%
@benchmark PFI(model)
# Out:
# UndefVarError: @benchmark not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at .\loading.jl:522

# %%
plot(agrid,pol_a ,color="blue", linewidth=1.5, label="Policy Function")
plot!(agrid,agrid, color="red", linewidth=1.5, label="45 degree Line")
# Out:
# UndefVarError: plot not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at .\loading.jl:522

# %%
plot(agrid,v0,color="blue",lw=1.5,label="value function")
# Out:
# <img src="data:image/png;base64,..." />

# %%
@code_warntype PFI(model)
# Out:
# Variables:
#   #self# <optimized out>
#   m::Model
#   j@_3::Int64
#   next::Float64
#   #temp#@_5 <optimized out>
#   c::Float64
#   #temp#@_7::Tuple{Int64,Int64}
#   i@_8::Int64
#   today::Float64
#   #temp#@_10 <optimized out>
#   #temp#@_11::Tuple{Int64,Int64}
#   v::Float64
#   j@_13::Int64
#   #temp#@_14::Int64
#   vmin::Float64
#   i@_16::Int64
#   #temp#@_17::Int64
#   i@_18::Int64
#   #temp#@_19::Int64
#   i@_20::Int64
#   #temp#@_21::Int64
#   iter@_22 <optimized out>
#   gridstart::Int64
#   Q::SparseMatrixCSC{Float64,Int64}
#   #temp#@_25::Int64
#   na::Int64
#   penalty <optimized out>
#   maxiter <optimized out>
#   tol <optimized out>
#   beta::Float64
#   sigma::Float64
#   alpha::Float64
#   delta::Float64
#   agrid::Array{Float64,1}
#   u::#u#1{Float64}
#   util::Array{Float64,2}
#   reward::Array{Float64,2}
#   v0::Array{Float64,2}
#   Tv::Array{Float64,2}
#   pol_a::Array{Float64,2}
#   a_index::Array{Int64,1}
#   I@_42::SparseMatrixCSC{Float64,Int64}
#   error::Float64
#   n@_44 <optimized out>
#   n@_45 <optimized out>
#   #temp#@_46::Float64
#   #temp#@_47::Float64
#   T <optimized out>
#   shape <optimized out>
#   iter@_50 <optimized out>
#   C::Array{Float64,2}
#   keeps@_52::Tuple{Tuple{Bool,Bool}}
#   Idefaults@_53::Tuple{Tuple{Int64,Int64}}
#   #temp#@_54 <optimized out>
#   keeps@_55 <optimized out>
#   Idefaults@_56 <optimized out>
#   #temp#@_57 <optimized out>
#   keep@_58::Tuple{Bool,Bool}
#   Idefault@_59::Tuple{Int64,Int64}
#   #temp#@_60 <optimized out>
#   ind1@_61 <optimized out>
#   keep@_62::Tuple{Bool}
#   Idefault@_63::Tuple{Int64}
#   #temp#@_64 <optimized out>
#   ind1@_65 <optimized out>
#   keep@_66 <optimized out>
#   Idefault@_67 <optimized out>
#   #temp#@_68 <optimized out>
#   I_1 <optimized out>
#   val_1::Float64
#   result::Float64
#   I@_72 <optimized out>
#   i#672::Int64
#   I@_74 <optimized out>
#   n#671::Int64
#   i#670 <optimized out>
#   #temp#@_77::CartesianIndex{1}
#   r#669 <optimized out>
#   A_1 <optimized out>
#   keep_1::Tuple{Bool,Bool}
#   Idefault_1::Tuple{Int64,Int64}
#   start::CartesianIndex{1}
#   stop <optimized out>
#   #5 <optimized out>
#   #temp#@_85::CartesianIndex{1}
#   #temp#@_86 <optimized out>
#
# Body:
#   begin
#       NewvarNode(:(error::Float64))
#       beta::Float64 = (Core.getfield)(m::Model, :beta)::Float64 # line 21:
#       sigma::Float64 = (Core.getfield)(m::Model, :sigma)::Float64 # line 22:
#       alpha::Float64 = (Core.getfield)(m::Model, :alpha)::Float64 # line 23:
#       delta::Float64 = (Core.getfield)(m::Model, :delta)::Float64 # line 25:
#       agrid::Array{Float64,1} = (Core.getfield)(m::Model, :agrid)::Array{Float64,1} # line 26:
#       na::Int64 = (Base.arraysize)(agrid::Array{Float64,1}, 1)::Int64 # line 29:
#       u::#u#1{Float64} = $(Expr(:new, #u#1{Float64}, :(sigma))) # line 36:
#       SSAValue(176) = na::Int64
#       SSAValue(177) = na::Int64
#       $(Expr(:inbounds, false))
#       # meta: location array.jl zeros 266
#       # meta: location array.jl zeros 264
#       # meta: location array.jl zeros 263
#       SSAValue(29) = SSAValue(176)
#       SSAValue(30) = SSAValue(177)
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       util::Array{Float64,2} = $(Expr(:invoke, MethodInstance for fill!(::Array{Float64,2}, ::Float64), :(Base.fill!), :($(Expr(:foreigncall, :(:jl_alloc_array_2d), Array{Float64,2}, svec(Any, Int64, Int64), Array{Float64,2}, 0, SSAValue(29), 0, SSAValue(30), 0))), :((Base.sitofp)(Float64, 0)::Float64))) # line 37:
#       SSAValue(178) = na::Int64
#       $(Expr(:inbounds, false))
#       # meta: location array.jl zeros 266
#       # meta: location array.jl zeros 264
#       # meta: location array.jl zeros 263
#       SSAValue(35) = SSAValue(178)
#       SSAValue(36) = 1
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       reward::Array{Float64,2} = $(Expr(:invoke, MethodInstance for fill!(::Array{Float64,2}, ::Float64), :(Base.fill!), :($(Expr(:foreigncall, :(:jl_alloc_array_2d), Array{Float64,2}, svec(Any, Int64, Int64), Array{Float64,2}, 0, SSAValue(35), 0, SSAValue(36), 0))), :((Base.sitofp)(Float64, 0)::Float64))) # line 38:
#       SSAValue(179) = na::Int64
#       $(Expr(:inbounds, false))
#       # meta: location array.jl zeros 266
#       # meta: location array.jl zeros 264
#       # meta: location array.jl zeros 263
#       SSAValue(41) = SSAValue(179)
#       SSAValue(42) = 1
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       v0::Array{Float64,2} = $(Expr(:invoke, MethodInstance for fill!(::Array{Float64,2}, ::Float64), :(Base.fill!), :($(Expr(:foreigncall, :(:jl_alloc_array_2d), Array{Float64,2}, svec(Any, Int64, Int64), Array{Float64,2}, 0, SSAValue(41), 0, SSAValue(42), 0))), :((Base.sitofp)(Float64, 0)::Float64))) # line 39:
#       SSAValue(180) = na::Int64
#       $(Expr(:inbounds, false))
#       # meta: location array.jl zeros 266
#       # meta: location array.jl zeros 264
#       # meta: location array.jl zeros 263
#       SSAValue(47) = SSAValue(180)
#       SSAValue(48) = 1
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       Tv::Array{Float64,2} = $(Expr(:invoke, MethodInstance for fill!(::Array{Float64,2}, ::Float64), :(Base.fill!), :($(Expr(:foreigncall, :(:jl_alloc_array_2d), Array{Float64,2}, svec(Any, Int64, Int64), Array{Float64,2}, 0, SSAValue(47), 0, SSAValue(48), 0))), :((Base.sitofp)(Float64, 0)::Float64))) # line 40:
#       SSAValue(181) = na::Int64
#       $(Expr(:inbounds, false))
#       # meta: location array.jl zeros 266
#       # meta: location array.jl zeros 264
#       # meta: location array.jl zeros 263
#       SSAValue(53) = SSAValue(181)
#       SSAValue(54) = 1
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       pol_a::Array{Float64,2} = $(Expr(:invoke, MethodInstance for fill!(::Array{Float64,2}, ::Float64), :(Base.fill!), :($(Expr(:foreigncall, :(:jl_alloc_array_2d), Array{Float64,2}, svec(Any, Int64, Int64), Array{Float64,2}, 0, SSAValue(53), 0, SSAValue(54), 0))), :((Base.sitofp)(Float64, 0)::Float64))) # line 41:
#       SSAValue(0) = $(Expr(:invoke, MethodInstance for fill!(::Array{Float64,1}, ::Float64), :(Base.fill!), :($(Expr(:foreigncall, :(:jl_alloc_array_1d), Array{Float64,1}, svec(Any, Int64), Array{Float64,1}, 0, :(na), 0))), :((Base.sitofp)(Float64, 0)::Float64)))
#       $(Expr(:inbounds, false))
#       # meta: location array.jl convert 373
#       SSAValue(59) = (Base.arraysize)(SSAValue(0), 1)::Int64
#       SSAValue(58) = $(Expr(:foreigncall, :(:jl_alloc_array_1d), Array{Int64,1}, svec(Any, Int64), Array{Int64,1}, 0, SSAValue(59), 0))
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       a_index::Array{Int64,1} = $(Expr(:invoke, MethodInstance for copy!(::IndexLinear, ::Array{Int64,1}, ::IndexLinear, ::Array{Float64,1}), :(Base.copy!), :($(QuoteNode(IndexLinear()))), SSAValue(58), :($(QuoteNode(IndexLinear()))), SSAValue(0))) # line 42:
#       I@_42::SparseMatrixCSC{Float64,Int64} = $(Expr(:invoke, MethodInstance for speye_scaled(::Type{Float64}, ::Float64, ::Int64, ::Int64), :(Base.SparseArrays.speye_scaled), Float64, :((Base.sitofp)(Float64, 1)::Float64), :(na), :(na))) # line 46:
#       SSAValue(182) = agrid::Array{Float64,1}
#       #temp#@_11::Tuple{Int64,Int64} = (1, 1)
#       95:
#       unless (Base.not_int)(((Base.getfield)(#temp#@_11::Tuple{Int64,Int64}, 2)::Int64 === (Base.add_int)((Base.arraylen)(SSAValue(182))::Int64, 1)::Int64)::Bool)::Bool goto 167
#       $(Expr(:inbounds, false))
#       # meta: location iterators.jl next 65
#       SSAValue(60) = (Base.getfield)(#temp#@_11::Tuple{Int64,Int64}, 2)::Int64
#       SSAValue(61) = (Base.arrayref)(SSAValue(182), SSAValue(60))::Float64
#       SSAValue(62) = (Base.add_int)(SSAValue(60), 1)::Int64
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       SSAValue(183) = (Core.tuple)((Base.getfield)(#temp#@_11::Tuple{Int64,Int64}, 1)::Int64, SSAValue(61))::Tuple{Int64,Float64}
#       SSAValue(184) = (Core.tuple)((Base.add_int)((Base.getfield)(#temp#@_11::Tuple{Int64,Int64}, 1)::Int64, 1)::Int64, SSAValue(62))::Tuple{Int64,Int64}
#       SSAValue(3) = SSAValue(183)
#       SSAValue(185) = (Base.getfield)(SSAValue(3), 1)::Int64
#       SSAValue(186) = (Base.add_int)(1, 1)::Int64
#       i@_8::Int64 = SSAValue(185)
#       SSAValue(187) = (Base.getfield)(SSAValue(3), 2)::Float64
#       SSAValue(188) = (Base.add_int)(2, 1)::Int64
#       today::Float64 = SSAValue(187)
#       #temp#@_11::Tuple{Int64,Int64} = SSAValue(184) # line 47:
#       SSAValue(189) = agrid::Array{Float64,1}
#       #temp#@_7::Tuple{Int64,Int64} = (1, 1)
#       117:
#       unless (Base.not_int)(((Base.getfield)(#temp#@_7::Tuple{Int64,Int64}, 2)::Int64 === (Base.add_int)((Base.arraylen)(SSAValue(189))::Int64, 1)::Int64)::Bool)::Bool goto 165
#       $(Expr(:inbounds, false))
#       # meta: location iterators.jl next 65
#       SSAValue(63) = (Base.getfield)(#temp#@_7::Tuple{Int64,Int64}, 2)::Int64
#       SSAValue(64) = (Base.arrayref)(SSAValue(189), SSAValue(63))::Float64
#       SSAValue(65) = (Base.add_int)(SSAValue(63), 1)::Int64
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       SSAValue(190) = (Core.tuple)((Base.getfield)(#temp#@_7::Tuple{Int64,Int64}, 1)::Int64, SSAValue(64))::Tuple{Int64,Float64}
#       SSAValue(191) = (Core.tuple)((Base.add_int)((Base.getfield)(#temp#@_7::Tuple{Int64,Int64}, 1)::Int64, 1)::Int64, SSAValue(65))::Tuple{Int64,Int64}
#       SSAValue(8) = SSAValue(190)
#       SSAValue(192) = (Base.getfield)(SSAValue(8), 1)::Int64
#       SSAValue(193) = (Base.add_int)(1, 1)::Int64
#       j@_3::Int64 = SSAValue(192)
#       SSAValue(194) = (Base.getfield)(SSAValue(8), 2)::Float64
#       SSAValue(195) = (Base.add_int)(2, 1)::Int64
#       next::Float64 = SSAValue(194)
#       #temp#@_7::Tuple{Int64,Int64} = SSAValue(191) # line 48:
#       $(Expr(:inbounds, false))
#       # meta: location math.jl ^ 699
#       SSAValue(68) = $(Expr(:foreigncall, "llvm.pow.f64", Float64, svec(Float64, Float64), :(today), 0, :(alpha), 0, :($(Expr(:llvmcall)))))
#       SSAValue(69) = (Base.add_float)(today::Float64, alpha::Float64)::Float64
#       # meta: location math.jl nan_dom_err 300
#       unless (Base.and_int)((Base.ne_float)(SSAValue(68), SSAValue(68))::Bool, (Base.not_int)((Base.ne_float)(SSAValue(69), SSAValue(69))::Bool)::Bool)::Bool goto 145
#       #temp#@_46::Float64 = (Base.Math.throw)($(QuoteNode(DomainError())))::Union{}
#       goto 147
#       145:
#       #temp#@_46::Float64 = SSAValue(68)
#       147:
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       c::Float64 = (Base.sub_float)((Base.add_float)(#temp#@_46::Float64, (Base.mul_float)((Base.sub_float)(1.0, delta::Float64)::Float64, today::Float64)::Float64)::Float64, next::Float64)::Float64 # line 49:
#       $(Expr(:inbounds, true))
#       SSAValue(11) = $(Expr(:invoke, MethodInstance for (::#u#1{Float64})(::Float64), :(u), :(c)))
#       (Base.arrayset)(util::Array{Float64,2}, SSAValue(11), i@_8::Int64, j@_3::Int64)::Array{Float64,2}
#       $(Expr(:inbounds, :pop)) # line 50:
#       unless (Base.le_float)(c::Float64, 0.0)::Bool goto 163 # line 51:
#       $(Expr(:inbounds, true))
#       (Base.arrayset)(util::Array{Float64,2}, -1.0e10, i@_8::Int64, j@_3::Int64)::Array{Float64,2}
#       $(Expr(:inbounds, :pop))
#       163:
#       goto 117
#       165:
#       goto 95
#       167:  # line 59:
#       error::Float64 = 10.0 # line 62:
#       SSAValue(196) = (Base.select_value)((Base.sle_int)(1, 1000)::Bool, 1000, (Base.sub_int)(1, 1)::Int64)::Int64
#       #temp#@_25::Int64 = 1
#       173:
#       unless (Base.not_int)((#temp#@_25::Int64 === (Base.add_int)(SSAValue(196), 1)::Int64)::Bool)::Bool goto 428
#       NewvarNode(:(Q::SparseMatrixCSC{Float64,Int64}))
#       SSAValue(197) = #temp#@_25::Int64
#       SSAValue(198) = (Base.add_int)(#temp#@_25::Int64, 1)::Int64
#       #temp#@_25::Int64 = SSAValue(198) # line 63:
#       gridstart::Int64 = 1 # line 65:
#       SSAValue(199) = (Base.select_value)((Base.sle_int)(1, na::Int64)::Bool, na::Int64, (Base.sub_int)(1, 1)::Int64)::Int64
#       #temp#@_17::Int64 = 1
#       184:
#       unless (Base.not_int)((#temp#@_17::Int64 === (Base.add_int)(SSAValue(199), 1)::Int64)::Bool)::Bool goto 220
#       SSAValue(200) = #temp#@_17::Int64
#       SSAValue(201) = (Base.add_int)(#temp#@_17::Int64, 1)::Int64
#       i@_16::Int64 = SSAValue(200)
#       #temp#@_17::Int64 = SSAValue(201) # line 66:
#       vmin::Float64 = -1.0e10 # line 67:
#       SSAValue(202) = gridstart::Int64
#       SSAValue(203) = (Base.select_value)((Base.sle_int)(gridstart::Int64, na::Int64)::Bool, na::Int64, (Base.sub_int)(gridstart::Int64, 1)::Int64)::Int64
#       #temp#@_14::Int64 = SSAValue(202)
#       196:
#       unless (Base.not_int)((#temp#@_14::Int64 === (Base.add_int)(SSAValue(203), 1)::Int64)::Bool)::Bool goto 218
#       SSAValue(204) = #temp#@_14::Int64
#       SSAValue(205) = (Base.add_int)(#temp#@_14::Int64, 1)::Int64
#       j@_13::Int64 = SSAValue(204)
#       #temp#@_14::Int64 = SSAValue(205) # line 69:
#       $(Expr(:inbounds, true))
#       v::Float64 = (Base.add_float)((Base.arrayref)(util::Array{Float64,2}, i@_16::Int64, j@_13::Int64)::Float64, (Base.mul_float)(beta::Float64, (Base.arrayref)(v0::Array{Float64,2}, j@_13::Int64)::Float64)::Float64)::Float64
#       $(Expr(:inbounds, :pop)) # line 70:
#       unless (Base.lt_float)(vmin::Float64, v::Float64)::Bool goto 216 # line 72:
#       vmin::Float64 = v::Float64 # line 73:
#       gridstart::Int64 = j@_13::Int64 # line 74:
#       $(Expr(:inbounds, true))
#       (Base.arrayset)(a_index::Array{Int64,1}, j@_13::Int64, i@_16::Int64)::Array{Int64,1}
#       $(Expr(:inbounds, :pop))
#       216:
#       goto 196
#       218:
#       goto 184
#       220:  # line 80:
#       Q::SparseMatrixCSC{Float64,Int64} = $(Expr(:invoke, MethodInstance for spzeros(::Type{Float64}, ::Type{Int64}, ::Int64, ::Int64), :(Base.SparseArrays.spzeros), Float64, :(Base.SparseArrays.Int), :(na), :(na))) # line 81:
#       SSAValue(206) = (Base.select_value)((Base.sle_int)(1, na::Int64)::Bool, na::Int64, (Base.sub_int)(1, 1)::Int64)::Int64
#       #temp#@_19::Int64 = 1
#       226:
#       unless (Base.not_int)((#temp#@_19::Int64 === (Base.add_int)(SSAValue(206), 1)::Int64)::Bool)::Bool goto 260
#       SSAValue(207) = #temp#@_19::Int64
#       SSAValue(208) = (Base.add_int)(#temp#@_19::Int64, 1)::Int64
#       i@_18::Int64 = SSAValue(207)
#       #temp#@_19::Int64 = SSAValue(208) # line 83:
#       $(Expr(:inbounds, true))
#       SSAValue(70) = (Base.arrayref)(agrid::Array{Float64,1}, i@_18::Int64)::Float64
#       $(Expr(:inbounds, false))
#       # meta: location math.jl ^ 699
#       SSAValue(73) = $(Expr(:foreigncall, "llvm.pow.f64", Float64, svec(Float64, Float64), SSAValue(70), 0, :(alpha), 0, :($(Expr(:llvmcall)))))
#       SSAValue(74) = (Base.add_float)(SSAValue(70), alpha::Float64)::Float64
#       $(Expr(:inbounds, false))
#       # meta: location math.jl nan_dom_err 300
#       unless (Base.and_int)((Base.ne_float)(SSAValue(73), SSAValue(73))::Bool, (Base.not_int)((Base.ne_float)(SSAValue(74), SSAValue(74))::Bool)::Bool)::Bool goto 244
#       #temp#@_47::Float64 = (Base.Math.throw)($(QuoteNode(DomainError())))::Union{}
#       goto 246
#       244:
#       #temp#@_47::Float64 = SSAValue(73)
#       246:
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       SSAValue(21) = $(Expr(:invoke, MethodInstance for (::#u#1{Float64})(::Float64), :(u), :((Base.sub_float)((Base.add_float)(#temp#@_47, (Base.mul_float)((Base.sub_float)(1.0, delta)::Float64, (Base.arrayref)(agrid, i@_18)::Float64)::Float64)::Float64, (Base.arrayref)(agrid, (Base.arrayref)(a_index, i@_18)::Int64)::Float64)::Float64)))
#       (Base.arrayset)(reward::Array{Float64,2}, SSAValue(21), i@_18::Int64)::Array{Float64,2}
#       $(Expr(:inbounds, :pop)) # line 84:
#       $(Expr(:inbounds, true))
#       $(Expr(:invoke, MethodInstance for setindex!(::SparseMatrixCSC{Float64,Int64}, ::Float64, ::Int64, ::Int64), :(Main.setindex!), :(Q), 1.0, :(i@_18), :((Base.arrayref)(a_index, i@_18)::Int64)))
#       $(Expr(:inbounds, :pop))
#       258:
#       goto 226
#       260:  # line 87:
#       SSAValue(75) = $(Expr(:invoke, MethodInstance for *(::Float64, ::SparseMatrixCSC{Float64,Int64}), :(Main.*), :(beta), :(Q)))
#       Tv::Array{Float64,2} = $(Expr(:invoke, MethodInstance for \(::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,2}), :(Main.\), :($(Expr(:invoke, MethodInstance for map(::Base.#-, ::SparseMatrixCSC{Float64,Int64}, ::SparseMatrixCSC{Float64,Int64}), :(Base.SparseArrays.map), :(Base.SparseArrays.-), :(I@_42), SSAValue(75)))), :(reward))) # line 89:
#       SSAValue(76) = $(Expr(:invoke, MethodInstance for -(::Array{Float64,2}, ::Array{Float64,2}), :(Main.-), :(Tv), :(v0)))
#       $(Expr(:inbounds, false))
#       # meta: location broadcast.jl broadcast 455
#       # meta: location broadcast.jl broadcast_c 313
#       # meta: location broadcast.jl broadcast_indices 48
#       # meta: location broadcast.jl broadcast_indices 52
#       # meta: location abstractarray.jl indices 64
#       SSAValue(80) = (Base.arraysize)(SSAValue(76), 1)::Int64
#       SSAValue(81) = (Base.arraysize)(SSAValue(76), 2)::Int64
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       SSAValue(170) = (Base.select_value)((Base.slt_int)(SSAValue(80), 0)::Bool, 0, SSAValue(80))::Int64
#       SSAValue(171) = (Base.select_value)((Base.slt_int)(SSAValue(81), 0)::Bool, 0, SSAValue(81))::Int64 # line 316:
#       # meta: location broadcast.jl broadcast_t 268
#       C::Array{Float64,2} = $(Expr(:foreigncall, :(:jl_alloc_array_2d), Array{Float64,2}, svec(Any, Int64, Int64), Array{Float64,2}, 0, SSAValue(170), 0, SSAValue(171), 0)) # line 269:
#       # meta: location broadcast.jl map_newindexer 125 # line 126:
#       # meta: location broadcast.jl newindexer 108
#       # meta: location broadcast.jl broadcast_indices 48
#       # meta: location broadcast.jl broadcast_indices 52
#       # meta: location abstractarray.jl indices 64
#       SSAValue(99) = (Base.arraysize)(SSAValue(76), 1)::Int64
#       SSAValue(100) = (Base.arraysize)(SSAValue(76), 2)::Int64
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       SSAValue(122) = (Base.select_value)((Base.slt_int)(SSAValue(99), 0)::Bool, 0, SSAValue(99))::Int64
#       SSAValue(123) = (Base.select_value)((Base.slt_int)(SSAValue(100), 0)::Bool, 0, SSAValue(100))::Int64
#       # meta: location broadcast.jl shapeindexer 111 # line 112:
#       SSAValue(112) = (Core.tuple)((Base.and_int)((Base.and_int)((1 === 1)::Bool, (1 === 1)::Bool)::Bool, (SSAValue(171) === SSAValue(123))::Bool)::Bool)::Tuple{Bool}
#       SSAValue(113) = (Core.tuple)(1)::Tuple{Int64}
#       keep@_62::Tuple{Bool} = SSAValue(112)
#       Idefault@_63::Tuple{Int64} = SSAValue(113)
#       # meta: pop location
#       # meta: pop location
#       SSAValue(124) = (Core.tuple)((Base.and_int)((Base.and_int)((1 === 1)::Bool, (1 === 1)::Bool)::Bool, (SSAValue(170) === SSAValue(122))::Bool)::Bool, (Core.getfield)(keep@_62::Tuple{Bool}, 1)::Bool)::Tuple{Bool,Bool}
#       SSAValue(125) = (Core.tuple)(1, (Core.getfield)(Idefault@_63::Tuple{Int64}, 1)::Int64)::Tuple{Int64,Int64}
#       keep@_58::Tuple{Bool,Bool} = SSAValue(124)
#       Idefault@_59::Tuple{Int64,Int64} = SSAValue(125)
#       # meta: pop location
#       SSAValue(161) = (Core.tuple)(keep@_58::Tuple{Bool,Bool})::Tuple{Tuple{Bool,Bool}}
#       SSAValue(162) = (Core.tuple)(Idefault@_59::Tuple{Int64,Int64})::Tuple{Tuple{Int64,Int64}}
#       keeps@_52::Tuple{Tuple{Bool,Bool}} = SSAValue(161)
#       Idefaults@_53::Tuple{Tuple{Int64,Int64}} = SSAValue(162) # line 270:
#       # meta: location broadcast.jl _broadcast! 141
#       # meta: location broadcast.jl # line 147:
#       keep_1::Tuple{Bool,Bool} = (Base.getfield)(keeps@_52::Tuple{Tuple{Bool,Bool}}, 1)::Tuple{Bool,Bool} # line 148:
#       Idefault_1::Tuple{Int64,Int64} = (Base.getfield)(Idefaults@_53::Tuple{Tuple{Int64,Int64}}, 1)::Tuple{Int64,Int64} # line 149:
#       # meta: location simdloop.jl # line 66:
#       # meta: location multidimensional.jl simd_outer_range 246
#       start::CartesianIndex{1} = $(Expr(:new, CartesianIndex{1}, :((Core.tuple)(1)::Tuple{Int64})))
#       # meta: pop location
#       # meta: location multidimensional.jl start 206
#       unless (Base.slt_int)(SSAValue(171), (Base.getfield)((Core.getfield)(start::CartesianIndex{1}, :I)::Tuple{Int64}, 1)::Int64)::Bool goto 334 # line 207:
#       # meta: location multidimensional.jl + 111
#       SSAValue(134) = (Core.tuple)((Base.add_int)(SSAValue(171), 1)::Int64)::Tuple{Int64}
#       # meta: pop location
#       #temp#@_85::CartesianIndex{1} = $(Expr(:new, CartesianIndex{1}, SSAValue(134)))
#       goto 337
#       334:  # line 209:
#       #temp#@_85::CartesianIndex{1} = start::CartesianIndex{1}
#       337:
#       # meta: pop location
#       #temp#@_77::CartesianIndex{1} = #temp#@_85::CartesianIndex{1}
#       340:
#       # meta: location multidimensional.jl done 224
#       SSAValue(136) = (Core.getfield)(#temp#@_77::CartesianIndex{1}, :I)::Tuple{Int64}
#       SSAValue(137) = (Base.getfield)(SSAValue(136), 1)::Int64
#       # meta: pop location
#       unless (Base.not_int)((Base.slt_int)(SSAValue(171), SSAValue(137))::Bool)::Bool goto 391
#       SSAValue(155) = #temp#@_77::CartesianIndex{1}
#       SSAValue(156) = $(Expr(:new, CartesianIndex{1}, :((Core.tuple)((Base.add_int)((Base.getfield)((Core.getfield)(#temp#@_77, :I)::Tuple{Int64}, 1)::Int64, 1)::Int64)::Tuple{Int64})))
#       #temp#@_77::CartesianIndex{1} = SSAValue(156) # line 67:
#       n#671::Int64 = (Base.add_int)((Base.sub_int)(SSAValue(170), 1)::Int64, 1)::Int64 # line 68:
#       unless (Base.slt_int)(0, n#671::Int64)::Bool goto 389 # line 70:
#       i#672::Int64 = 0 # line 71:
#       NewvarNode(:(val_1::Float64))
#       NewvarNode(:(result::Float64))
#       358:
#       unless (Base.slt_int)(i#672::Int64, n#671::Int64)::Bool goto 387 # line 72:
#       SSAValue(166) = (Base.add_int)(i#672::Int64, 1)::Int64
#       SSAValue(167) = (Core.getfield)((Core.getfield)(SSAValue(155), :I)::Tuple{Int64}, 1)::Int64 # line 73:
#       # meta: location broadcast.jl # line 151:
#       SSAValue(159) = (Base.select_value)((Base.getfield)(keep_1::Tuple{Bool,Bool}, 1)::Bool, SSAValue(166), (Base.getfield)(Idefault_1::Tuple{Int64,Int64}, 1)::Int64)::Int64
#       SSAValue(160) = (Base.select_value)((Core.getfield)(keep_1::Tuple{Bool,Bool}, 2)::Bool, SSAValue(167), (Core.getfield)(Idefault_1::Tuple{Int64,Int64}, 2)::Int64)::Int64 # line 153:
#       $(Expr(:inbounds, true))
#       val_1::Float64 = (Base.arrayref)(SSAValue(76), SSAValue(159), SSAValue(160))::Float64
#       $(Expr(:inbounds, :pop)) # line 155:
#       result::Float64 = (Base.abs_float)(val_1::Float64)::Float64 # line 156:
#       $(Expr(:inbounds, true))
#       # meta: location multidimensional.jl setindex! 300
#       (Base.arrayset)(C::Array{Float64,2}, result::Float64, SSAValue(166), SSAValue(167))::Array{Float64,2}
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       # meta: pop location # line 74:
#       i#672::Int64 = (Base.add_int)(i#672::Int64, 1)::Int64 # line 75:
#       $(Expr(:simdloop))
#       385:
#       goto 358
#       387:  # line 79:
#       389:
#       goto 340
#       391:
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       # meta: pop location
#       goto 398 # line 321:
#       398:
#       # meta: pop location
#       # meta: pop location
#       $(Expr(:inbounds, :pop))
#       error::Float64 = $(Expr(:invoke, MethodInstance for _mapreduce(::Base.#identity, ::Base.#scalarmax, ::IndexLinear, ::Array{Float64,2}), :(Base._mapreduce), :(Base.identity), :(Base.scalarmax), :($(QuoteNode(IndexLinear()))), :(C))) # line 90:
#       v0::Array{Float64,2} = $(Expr(:foreigncall, :(:jl_array_copy), Ref{Array{Float64,2}}, svec(Any), :(Tv), 0)) # line 92:
#       unless (Base.lt_float)(error::Float64, 1.0e-5)::Bool goto 426 # line 93:
#       SSAValue(209) = (Base.select_value)((Base.sle_int)(1, na::Int64)::Bool, na::Int64, (Base.sub_int)(1, 1)::Int64)::Int64
#       #temp#@_21::Int64 = 1
#       410:
#       unless (Base.not_int)((#temp#@_21::Int64 === (Base.add_int)(SSAValue(209), 1)::Int64)::Bool)::Bool goto 423
#       SSAValue(210) = #temp#@_21::Int64
#       SSAValue(211) = (Base.add_int)(#temp#@_21::Int64, 1)::Int64
#       i@_20::Int64 = SSAValue(210)
#       #temp#@_21::Int64 = SSAValue(211) # line 94:
#       $(Expr(:inbounds, true))
#       SSAValue(24) = (Base.arrayref)(agrid::Array{Float64,1}, (Base.arrayref)(a_index::Array{Int64,1}, i@_20::Int64)::Int64)::Float64
#       (Base.arrayset)(pol_a::Array{Float64,2}, SSAValue(24), i@_20::Int64)::Array{Float64,2}
#       $(Expr(:inbounds, :pop))
#       421:
#       goto 410
#       423:  # line 96:
#       goto 428
#       426:
#       goto 173
#       428:  # line 100:
#       return (Core.tuple)(agrid::Array{Float64,1}, v0::Array{Float64,2}, pol_a::Array{Float64,2})::Tuple{Array{Float64,1},Array{Float64,2},Array{Float64,2}}
#   end::Tuple{Array{Float64,1},Array{Float64,2},Array{Float64,2}}
